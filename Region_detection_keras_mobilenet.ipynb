# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanisthani/Region_detection_unmask_mobilenet/blob/main/Region_detection_keras_mobilenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import lib

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Mount g drive

# %%
#mount drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Add dataset path

# %%
import pathlib
data_dir='/content/gdrive/MyDrive/Region_detection/data/new_images'
data_dir = pathlib.Path(data_dir).with_suffix('')

# %% [markdown]
# Pre process the data

# %%
# Define the image size and batch size
img_size = (160, 160)
batch_size = 32

# Load the training and validation datasets
train_dataset = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

validation_dataset = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 100 files belonging to 2 classes.
# Using 80 files for training.
# Found 100 files belonging to 2 classes.
# Using 20 files for validation.

# %% [markdown]
# Find clas names

# %%
class_names = train_dataset.class_names
print(class_names)
# Out:
# ['EastAsian', 'SouthAsian']

# %% [markdown]
# Config dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Data agumentation

# %%
from tensorflow import keras
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(160,
                                  160,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Visulaize data agumentation

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Dropout

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Load pre trained model

# %%
pretrained_model = tf.keras.applications.MobileNetV2(input_shape=(160, 160, 3),
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %% [markdown]
# Freeze convolutional base

# %%
pretrained_model.trainable = False

# %% [markdown]
# Add classification head

# %%
model = models.Sequential([
  pretrained_model,
  layers.GlobalAveragePooling2D(),
  layers.Dense(1)
])

# %% [markdown]
# Compile model

# %%
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Train model

# %%
epochs = 20
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5137 - accuracy: 0.7375 - val_loss: 0.4523 - val_accuracy: 0.8000
# Epoch 2/20
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5062 - accuracy: 0.7375 - val_loss: 0.4449 - val_accuracy: 0.8000
# Epoch 3/20
# 3/3 [==============================] - 1s 122ms/step - loss: 0.4992 - accuracy: 0.7375 - val_loss: 0.4385 - val_accuracy: 0.8000
# Epoch 4/20
# 3/3 [==============================] - 1s 135ms/step - loss: 0.4921 - accuracy: 0.7375 - val_loss: 0.4318 - val_accuracy: 0.8000
# Epoch 5/20
# 3/3 [==============================] - 1s 190ms/step - loss: 0.4854 - accuracy: 0.7625 - val_loss: 0.4257 - val_accuracy: 0.8000
# Epoch 6/20
# 3/3 [==============================] - 1s 123ms/step - loss: 0.4792 - accuracy: 0.7625 - val_loss: 0.4197 - val_accuracy: 0.8000
# Epoch 7/20
# 3/3 [==============================] - 1s 107ms/step - loss: 0.4728 - accuracy: 0.7625 - val_loss: 0.4138 - val_accuracy: 0.8000
# Epoch 8/20
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4666 - accuracy: 0.7625 - val_loss: 0.4091 - val_accuracy: 0.8000
# Epoch 9/20
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4603 - accuracy: 0.7625 - val_loss: 0.4042 - val_accuracy: 0.8000
# Epoch 10/20
# 3/3 [==============================] - 0s 86ms/step - loss: 0.4547 - accuracy: 0.7750 - val_loss: 0.4000 - val_accuracy: 0.8000
# Epoch 11/20
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4488 - accuracy: 0.7750 - val_loss: 0.3950 - val_accuracy: 0.8000
# Epoch 12/20
# 3/3 [==============================] - 0s 88ms/step - loss: 0.4433 - accuracy: 0.8000 - val_loss: 0.3901 - val_accuracy: 0.8000
# Epoch 13/20
# 3/3 [==============================] - 0s 86ms/step - loss: 0.4379 - accuracy: 0.8000 - val_loss: 0.3852 - val_accuracy: 0.8500
# Epoch 14/20
# 3/3 [==============================] - 0s 88ms/step - loss: 0.4327 - accuracy: 0.8000 - val_loss: 0.3811 - val_accuracy: 0.8500
# Epoch 15/20
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4274 - accuracy: 0.8000 - val_loss: 0.3759 - val_accuracy: 0.8500
# Epoch 16/20
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4225 - accuracy: 0.8125 - val_loss: 0.3702 - val_accuracy: 0.9000
# Epoch 17/20
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4179 - accuracy: 0.8375 - val_loss: 0.3653 - val_accuracy: 0.9000
# Epoch 18/20
# 3/3 [==============================] - 1s 137ms/step - loss: 0.4133 - accuracy: 0.8375 - val_loss: 0.3605 - val_accuracy: 0.9000
# Epoch 19/20
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4088 - accuracy: 0.8500 - val_loss: 0.3563 - val_accuracy: 0.9000
# Epoch 20/20
# 3/3 [==============================] - 0s 85ms/step - loss: 0.4046 - accuracy: 0.8750 - val_loss: 0.3524 - val_accuracy: 0.9000

# %% [markdown]
# Evaluation

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# plt.figure(figsize=(8, 8))
# plt.subplot(2, 1, 2)
# plt.plot(acc, label='Training Accuracy')
# plt.plot(val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.ylabel('Accuracy')
# plt.ylim([min(plt.ylim()),1])
# plt.title('Training and Validation Accuracy')

# plt.subplot(2, 1, 2)
# plt.plot(loss, label='Training Loss')
# plt.plot(val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.ylabel('Cross Entropy')
# plt.ylim([0,1.0])
# plt.title('Training and Validation Loss')
# plt.xlabel('epoch')
# plt.show()


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Testing model

# %%
def predict_image(model, img_path):
    # Preprocess the image
    img_array = load_and_preprocess_image(img_path)

    # Make predictions
    predictions = model.predict(img_array)

    print(predictions[0] )
    # Decode the predictions to the original labels
    predicted_label = "East Asian" if predictions[0] > 0 else "South asian"

    return predicted_label

# %%
import cv2
from tensorflow.keras.preprocessing import image

def load_and_preprocess_image(img_path):
    # Load the image file, resizing it to the input size of our model
    img = image.load_img(img_path, target_size=img_size)

    # Convert the image to array
    img_array = image.img_to_array(img)

    # Normalize the image pixels
    img_array /= 255.0

    # Expand dimensions to fit the batch size
    img_array = np.expand_dims(img_array, axis=0)

    return img_array

# %%
img_path = "/content/gdrive/MyDrive/Region_detection/data/test_image/sa4.jpg"  # Replace with the path of your image
predicted_label = predict_image(model, img_path)

print(f"The model predicts that the image is a {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [1.3949302]
# The model predicts that the image is a East Asian

# %% [markdown]
# Find accuracy

# %%
# Evaluate on the validation set
evaluation = model.evaluate(validation_dataset)

# Print the evaluation results
print(f"Evaluation Results: {evaluation}")
print(f"Accuracy: {evaluation[1]*100:.2f}%")
# print(f"Precision: {evaluation[2]*100:.2f}%")
# print(f"Recall: {evaluation[3]*100:.2f}%")
# Out:
# 1/1 [==============================] - 0s 116ms/step - loss: 0.3524 - accuracy: 0.9000
# Evaluation Results: [0.3523930609226227, 0.8999999761581421]
# Accuracy: 90.00%
